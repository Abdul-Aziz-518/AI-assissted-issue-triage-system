# %%
import pandas as pd
from datetime import datetime
df=pd.read_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv", index_col="TicketID")
def _issue():
    ticket_id = f"TCKT-{len(df) + 1:04d}"
    df.loc[ticket_id] = {
        "Name": input("Enter your name"),
        "RollNumber": input("Enter your Roll Number"),
        "Location": input("Enter the location of the issue"),
        "IssueDescription": input("Enter your issue in detail"),
        "Date": datetime.now().date(),
        "Time": datetime.now().time(),
        "Status": "Open"
    }

    df.to_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv")

def update():
    t=input("Enter your complete ticketID: ")
    if t in df.index:
        print("Current Stautus:", df.loc[t]["Status"])
        c=input("Do you want to update the current status. Enter only=(Y/N)")
        if c=="Y":
            if df.loc[t]["Status"]=="Open":
                df.loc[t,"Status"]="In Progress"
            elif df.loc[t]["Status"]=="In Progress":
                df.loc[t,"Status"]="Closed"
            else:
                print("Status of your ticket:",df.loc[t,"Status"])
                print("Thank You")
            print("Status Updated. Current Status:", df.loc[t]["Status"])
        elif c=="N":
            print("Thank You")
        else:
            print("Invalid entry")
    else:
        print("Invalid entry, No such Id exists")
    df.to_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv")

# %%
df=pd.read_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv")
df=df.assign(TicketID=None)

# %%
import pandas as pd
df=pd.read_csv("issues.csv")
print(df)
print(df["Location"].value_counts())

# %%
_issue()

# %%
update()
# Out:
# Current Stautus: Open
# Status Updated. Current Status: In Progress

# %%
print(df)
# Out:
#            Name  RollNumber Location IssueDescription        Date  \
# TicketID
# TCKT-0001     A           1     Home             fire  2026-01-11
# TCKT-0002     B           2     Hall            Water  2026-01-11
# TCKT-0003     D           4     Road             Dead  2026-01-11
# 3             E           5       ad               fg  2026-01-11
# TCKT-0005  Aziz  25N31A6602  Canteen         Bad Food  2026-01-11
#
#                       Time       Status
# TicketID
# TCKT-0001  00:11:54.612247         Open
# TCKT-0002  00:12:11.500734         Open
# TCKT-0003  02:17:31.757027         Open
# 3          02:21:40.271963         Open
# TCKT-0005  02:31:14.281357  In Progress

# %%
import random
print(random.randint(1,10000))

# %%
from datetime import datetime 
print(str(datetime.now().microsecond)[:4])

# %%
import pandas as pd
df=pd.read_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv", index_col="TicketID")
#Any changes here
#df["Status"]="Open"
print(df.loc["TCKT-0002"])
df.to_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv")

# %%
df = pd.read_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv")
print(df.columns.tolist())
