# %%
import pandas as pd
from datetime import datetime
df=pd.read_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv")
def _issue(): 
    df.loc[len(df)]={
    "Name": input("Enter your name"),
    "RollNumber": input("Enter your Roll Number"),
    "Location": input("Enter the location of the issue"),
    "IssueDescription": input("Enter your issue in detail"),
    "Date": datetime.now().date(),
    "Time": datetime.now().time(),
    "TicketID": f"TCKT-{len(df)+1:04d}"
    }
    df.to_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv", index=False)

# %%
df=pd.read_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv")
df=df.assign(TicketID=None)

# %%
import pandas as pd
df=pd.read_csv("issues.csv")
print(df)
print(df["Location"].value_counts())

# %%
_issue()

# %%
print(df)
# Out:
#     TicketID Name RollNumber Location IssueDescription        Date  \
# 0  TCKT-0001    A          1     Home             fire  2026-01-11
# 1  TCKT-0002    B          2     Hall            Water  2026-01-11
# 2  TCKT-0003    C          3  Canteen             Food  2026-01-11
#
#               Time
# 0  00:11:54.612247
# 1  00:12:11.500734
# 2  00:12:37.346294

# %%
import random
print(random.randint(1,10000))

# %%
from datetime import datetime 
print(str(datetime.now().microsecond)[:4])

# %%
import pandas as pd
df=pd.read_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv")
#Any changes here
df.to_csv("C:/Users/abdul/OneDrive/Desktop/AI assissted issue triage system/data/issues.csv", index=False)
