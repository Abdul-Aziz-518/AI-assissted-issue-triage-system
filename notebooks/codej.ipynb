# %%
import pandas as pd
from datetime import datetime
df=pd.read_csv("issues.csv")
def _issue(): 
    df.loc[len(df)]={
    "Name": input("Enter your name"),
    "RollNumber": input("Enter your Roll Number"),
    "Location": input("Enter the location of the issue"),
    "IssueDescription": input("Enter your issue in detail"),
    "Date": datetime.now().date(),
    "Time": datetime.now().time() 
    }
    df.to_csv("issues.csv", index=True)

# %%
import pandas as pd
df=pd.read_csv("issues.csv")
print(df)
print(df["Location"].value_counts())
# Out:
#    Unnamed: 0       Name  RollNumber  Location IssueDescription        Date  \
# 0           0  Herobrine  25N31A6602  HS Block   Unhygenic area  08/01/2026
# 1           1          A      123456      Hall             dead  2026-01-09
# 2           2          B      987654      Hall            Alive  2026-01-09
# 3           3          C      456789      Well            Water  2026-01-09
#
#               Time
# 0         01:12:20
# 1  17:40:21.900679
# 2  17:40:39.420056
# 3  17:41:24.997856
# Location
# Hall        2
# HS Block    1
# Well        1
# Name: count, dtype: int64

# %%
_issue()

# %%
print(df)
# Out:
#         Name  RollNumber  Location IssueDescription        Date  \
# 0  Herobrine  25N31A6602  HS Block   Unhygenic area  08/01/2026
# 1          A      123456      Hall             dead  2026-01-09
# 2          B      987654      Hall            Alive  2026-01-09
# 3          C      456789      Well            Water  2026-01-09
#
#               Time
# 0         01:12:20
# 1  17:40:21.900679
# 2  17:40:39.420056
# 3  17:41:24.997856
